# %%
dbutils.fs.ls("/")

# %%
dbutils.fs.ls("/")

# %%
df = spark.read.format("csv").options(header=True, inferSchema=True).load("/Volumes/sree_catalog/user6/casestudy/editorial_papers_data.csv")
display(df)
